# %% [markdown]
# # Task 0: Fashion MNIST classification in Pytorch (10 points)
#
# The goal of this task is to get you familiar with [Pytorch](https://pytorch.org/), teach you to debug your models, and give you a general understanding of deep learning and computer vision work-flows.
#
# [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) is a dataset of [Zalando’s](https://jobs.zalando.com/tech/) article images — consisting of 70,000 grayscale images in 10
# categories. Each example is a 28x28 grayscale image, associated with a label from 10 classes. ‘Fashion-
# MNIST’ is intended to serve as a direct **drop-in replacement** for the original [MNIST](http://yann.lecun.com/exdb/mnist/) dataset — often
# used as the “Hello, World” of machine learning programs for computer vision. It shares the same image
# size and structure of training and testing splits. We will use 60,000 images to train the network and
# 10,000 images to evaluate how accurately the network learned to classify images.

# %% [markdown]
# ### Prerequisites:
#
# - Install [conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/index.html) and create a conda environment to manage all the packages for the homeworks.
# - Install the following packages in your conda environment:
#     - [jupyterlab](https://jupyter.org/install) and get familiar with basic operations on jupyter notebook.
#     - [Pytorch](https://pytorch.org/)
#     - matplotlib
#     - tensorboard
#     - imageio
#     - sklearn

# %%
# installation directions can be found on pytorch's webpage
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
# %matplotlib inline

# import our network module from simple_cnn.py
from simple_cnn import SimpleCNN              # be sure to modify or you may have to restart kernel!

# %% [markdown]
# Usually you'll parse arguments using `argparse` (or similar library) but we can simply use a stand-in object for ipython notebooks. Furthermore, PyTorch can do computations on NVidia `GPU`s or on normal `CPU`s. You can configure the setting using the `device` variable.

# %%
class ARGS(object):
    # input batch size for training 
    batch_size = 64
    # input batch size for testing
    test_batch_size=1000
    # number of epochs to train for
    epochs = 14
    # learning rate
    lr = 1e-3
    # Learning rate step gamma
    gamma = 0.7
    # how many batches to wait before logging training status
    log_every = 100
    # how many batches to wait before evaluating model
    val_every = 100
    # set true if using GPU during training
    use_cuda = False

args = ARGS()
device = torch.device("cuda" if args.use_cuda else "cpu")

# %% [markdown]
# We define some basic testing and training code. The testing code prints out the average test loss and the training code (`main`) plots train/test losses and returns the final model.

# %%
def test(model, device, test_loader):
    """Evaluate model on test dataset."""
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True) 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

    return test_loss, correct / len(test_loader.dataset)

def main():
    # 1. load dataset and build dataloader
    train_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST('../data', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=args.batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST('../data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=args.test_batch_size, shuffle=True)

    # 2. define the model, and optimizer.
    model = SimpleCNN().to(device)
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=args.gamma)
    cnt = 0
    train_log = {'iter': [], 'loss': [], 'accuracy': []}
    test_log = {'iter': [], 'loss': [], 'accuracy': []}
    correct=0
    for epoch in range(args.epochs):
        
        for batch_idx, (data, target) in enumerate(train_loader):
            
            # Get a batch of data
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            # Forward pass
            output = model(data)
            # Calculate the loss
            loss = F.cross_entropy(output, target)          
            # Calculate gradient w.r.t the loss
            loss.backward()
            # Optimizer takes one step
            optimizer.step()
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            train_acc = correct/(args.batch_size*(cnt+1))
            # Log info
            if cnt % args.log_every == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch, cnt, len(train_loader.dataset),
                           100. * batch_idx / len(train_loader), loss.item()))
                train_log['iter'].append(cnt)
                train_log['loss'].append(loss.cpu().detach().numpy())
                # TODO: q0.1 calculate your train accuracy
                train_log['accuracy'].append(train_acc)
            # Validation iteration
            if cnt % args.val_every == 0:
                test_loss, test_acc = test(model, device, test_loader)
                test_log['iter'].append(cnt)
                test_log['loss'].append(test_loss)
                test_log['accuracy'].append(test_acc)
                model.train()
            cnt += 1
        scheduler.step()
    fig = plt.figure()
    plt.plot(train_log['iter'], train_log['loss'], 'r', label='Training')
    plt.plot(test_log['iter'], test_log['loss'], 'b', label='Testing')
    plt.title('Loss')
    plt.legend()
    fig = plt.figure()
    plt.plot(train_log['iter'], train_log['accuracy'], 'r', label='Training')
    plt.plot(test_log['iter'], test_log['accuracy'], 'b', label='Testing')
    plt.title('Accuracy')
    plt.legend()
    plt.show()
    return model

# %% [markdown]
# ## 0.1 Bug Fix and Hyper-parameter search. (2pts)
#
# Simply running `main` will result in a `RuntimeError`!
# - (1 pt) Check out `TODO: q0.1` in  `simple_cnn.py` and see if you can fix the bug. You may have to restart your ipython kernel for changes to reflect in the notebook.
# - (1 pt) Fill in the `TODO: q0.1` in the `main()` function above to calculated the train accuracy.
#
#
# Once you fix the bugs, you should be able to get a reasonable accuracy (>80%) within 100 iterations just by tuning some hyper-parameter. Include the train/test plots of your best hyperparamter setting and comment on why you think these settings worked best. (you can complete this task on CPU)
#
# **YOUR ANSWER HERE**

# %%
#### FEEL FREE TO MODIFY args VARIABLE HERE OR ABOVE ####
# args.gamma = float('inf')


# DON'T CHANGE
# prints out arguments and runs main
for attr in dir(args):
    if '__' not in attr and attr !='use_cuda':
        print('args.{} = {}'.format(attr, getattr(args, attr)))
print('\n\n')
model = main()
# Out:
# args.batch_size = 64
# args.epochs = 14
# args.gamma = 0.7
# args.log_every = 100
# args.lr = 1.0
# args.test_batch_size = 1000
# args.val_every = 100
#
#
#
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.312607
#
# Test set: Average loss: 397049.8272, Accuracy: 2295/10000 (23%)
#
# Train Epoch: 0 [100/60000 (11%)]	Loss: 12048011.000000
#
# Test set: Average loss: 8758360.2176, Accuracy: 6776/10000 (68%)
#
# Train Epoch: 0 [200/60000 (21%)]	Loss: 1243009.500000
#
# Test set: Average loss: 1632078.4640, Accuracy: 6919/10000 (69%)
#
# Train Epoch: 0 [300/60000 (32%)]	Loss: 1219312.375000
#
# Test set: Average loss: 1387094.7968, Accuracy: 6991/10000 (70%)
#
# Train Epoch: 0 [400/60000 (43%)]	Loss: 554772.187500
#
# Test set: Average loss: 484164.2400, Accuracy: 7363/10000 (74%)
#
# Train Epoch: 0 [500/60000 (53%)]	Loss: 482067.125000
#
# Test set: Average loss: 492663.6864, Accuracy: 6573/10000 (66%)
#
# Train Epoch: 0 [600/60000 (64%)]	Loss: 204323.062500
#
# Test set: Average loss: 293147.1280, Accuracy: 7826/10000 (78%)
#
# Train Epoch: 0 [700/60000 (75%)]	Loss: 250645.281250
#
# Test set: Average loss: 351392.6016, Accuracy: 6674/10000 (67%)
#
# Train Epoch: 0 [800/60000 (85%)]	Loss: 66417.851562
#
# Test set: Average loss: 142277.9200, Accuracy: 7812/10000 (78%)
#
# Train Epoch: 0 [900/60000 (96%)]	Loss: 78218.250000
#
# Test set: Average loss: 195534.3552, Accuracy: 7219/10000 (72%)
#
# Train Epoch: 1 [1000/60000 (7%)]	Loss: 195341.328125
#
# Test set: Average loss: 139030.5768, Accuracy: 7467/10000 (75%)
#
# Train Epoch: 1 [1100/60000 (17%)]	Loss: 94319.523438
#
# Test set: Average loss: 107054.0568, Accuracy: 7177/10000 (72%)
#
# Train Epoch: 1 [1200/60000 (28%)]	Loss: 49833.433594
#
# Test set: Average loss: 83000.5088, Accuracy: 7455/10000 (75%)
#
# Train Epoch: 1 [1300/60000 (39%)]	Loss: 96367.164062
#
# Test set: Average loss: 161700.5328, Accuracy: 7583/10000 (76%)
#
# Train Epoch: 1 [1400/60000 (49%)]	Loss: 80217.117188
#
# Test set: Average loss: 109126.6456, Accuracy: 7809/10000 (78%)
#
# Train Epoch: 1 [1500/60000 (60%)]	Loss: 85367.093750
#
# Test set: Average loss: 81264.0160, Accuracy: 7750/10000 (78%)
#
# Train Epoch: 1 [1600/60000 (71%)]	Loss: 78979.640625
#
# Test set: Average loss: 45311.4168, Accuracy: 7922/10000 (79%)
#
# Train Epoch: 1 [1700/60000 (81%)]	Loss: 52323.824219
#
# Test set: Average loss: 68161.6116, Accuracy: 7697/10000 (77%)
#
# Train Epoch: 1 [1800/60000 (92%)]	Loss: 50837.406250
#
# Test set: Average loss: 46295.8908, Accuracy: 7410/10000 (74%)
#
# Train Epoch: 2 [1900/60000 (3%)]	Loss: 40015.507812
#
# Test set: Average loss: 35276.4442, Accuracy: 7869/10000 (79%)
#
# Train Epoch: 2 [2000/60000 (13%)]	Loss: 35518.773438
#
# Test set: Average loss: 33087.2698, Accuracy: 7691/10000 (77%)
#
# Train Epoch: 2 [2100/60000 (24%)]	Loss: 24211.734375
#
# Test set: Average loss: 47518.9104, Accuracy: 7475/10000 (75%)
#
# Train Epoch: 2 [2200/60000 (35%)]	Loss: 16386.523438
#
# Test set: Average loss: 34771.2820, Accuracy: 7857/10000 (79%)
#
# Train Epoch: 2 [2300/60000 (45%)]	Loss: 23058.625000
#
# Test set: Average loss: 46622.2368, Accuracy: 7585/10000 (76%)
#
# Train Epoch: 2 [2400/60000 (56%)]	Loss: 34812.996094
#
# Test set: Average loss: 29480.1716, Accuracy: 7988/10000 (80%)
#
# Train Epoch: 2 [2500/60000 (67%)]	Loss: 25694.041016
#
# Test set: Average loss: 34523.9324, Accuracy: 7982/10000 (80%)
#
# Train Epoch: 2 [2600/60000 (77%)]	Loss: 31709.791016
#
# Test set: Average loss: 27539.5282, Accuracy: 7746/10000 (77%)
#
# Train Epoch: 2 [2700/60000 (88%)]	Loss: 14449.898438
#
# Test set: Average loss: 36121.4672, Accuracy: 7138/10000 (71%)
#
# Train Epoch: 2 [2800/60000 (99%)]	Loss: 44262.812500
#
# Test set: Average loss: 27764.8562, Accuracy: 7741/10000 (77%)
#
# Train Epoch: 3 [2900/60000 (9%)]	Loss: 25047.906250
#
# Test set: Average loss: 30002.3490, Accuracy: 7819/10000 (78%)
#
# Train Epoch: 3 [3000/60000 (20%)]	Loss: 22910.412109
#
# Test set: Average loss: 18822.0390, Accuracy: 7805/10000 (78%)
#
# Train Epoch: 3 [3100/60000 (30%)]	Loss: 24731.138672
#
# Test set: Average loss: 24231.7715, Accuracy: 7643/10000 (76%)
#
# Train Epoch: 3 [3200/60000 (41%)]	Loss: 21585.263672
#
# Test set: Average loss: 26354.8700, Accuracy: 7693/10000 (77%)
#
# Train Epoch: 3 [3300/60000 (52%)]	Loss: 20709.992188
#
# Test set: Average loss: 22153.8628, Accuracy: 7844/10000 (78%)
#
# Train Epoch: 3 [3400/60000 (62%)]	Loss: 55502.058594
#
# Test set: Average loss: 41626.4328, Accuracy: 6931/10000 (69%)
#
# Train Epoch: 3 [3500/60000 (73%)]	Loss: 75422.078125
#
# Test set: Average loss: 27593.0150, Accuracy: 7948/10000 (79%)
#
# Train Epoch: 3 [3600/60000 (84%)]	Loss: 11968.501953
#
# Test set: Average loss: 30157.4214, Accuracy: 7494/10000 (75%)
#
# Train Epoch: 3 [3700/60000 (94%)]	Loss: 36278.343750
#
# Test set: Average loss: 27150.8472, Accuracy: 7673/10000 (77%)
#
# Train Epoch: 4 [3800/60000 (5%)]	Loss: 25707.771484
#
# Test set: Average loss: 25807.9140, Accuracy: 7448/10000 (74%)
#
# Train Epoch: 4 [3900/60000 (16%)]	Loss: 9102.567383
#
# Test set: Average loss: 14029.5472, Accuracy: 7927/10000 (79%)
#
# Train Epoch: 4 [4000/60000 (26%)]	Loss: 8871.194336
#
# Test set: Average loss: 13978.4788, Accuracy: 7801/10000 (78%)
#
# Train Epoch: 4 [4100/60000 (37%)]	Loss: 13115.007812
#
# Test set: Average loss: 18382.8211, Accuracy: 8154/10000 (82%)
#
# Train Epoch: 4 [4200/60000 (48%)]	Loss: 22336.007812
#
# Test set: Average loss: 21431.7032, Accuracy: 7663/10000 (77%)
#
# Train Epoch: 4 [4300/60000 (58%)]	Loss: 18068.472656
#
# Test set: Average loss: 14834.9415, Accuracy: 7927/10000 (79%)
#
# Train Epoch: 4 [4400/60000 (69%)]	Loss: 20645.648438
#
# Test set: Average loss: 15621.4706, Accuracy: 8090/10000 (81%)
#
# Train Epoch: 4 [4500/60000 (80%)]	Loss: 5360.923828
#
# Test set: Average loss: 10950.1410, Accuracy: 8076/10000 (81%)
#
# Train Epoch: 4 [4600/60000 (90%)]	Loss: 7155.088379
#
# Test set: Average loss: 17319.7359, Accuracy: 7667/10000 (77%)
#
# Train Epoch: 5 [4700/60000 (1%)]	Loss: 11478.277344
#
# Test set: Average loss: 16127.5045, Accuracy: 7556/10000 (76%)
#
# Train Epoch: 5 [4800/60000 (12%)]	Loss: 6467.141602
#
# Test set: Average loss: 13287.4510, Accuracy: 7768/10000 (78%)
#
# Train Epoch: 5 [4900/60000 (22%)]	Loss: 15308.524414
#
# Test set: Average loss: 10255.6062, Accuracy: 7760/10000 (78%)
#
# Train Epoch: 5 [5000/60000 (33%)]	Loss: 5184.583984
#
# Test set: Average loss: 11468.8273, Accuracy: 7598/10000 (76%)
#
# Train Epoch: 5 [5100/60000 (44%)]	Loss: 9908.671875
#
# Test set: Average loss: 10643.2274, Accuracy: 7655/10000 (77%)
#
# Train Epoch: 5 [5200/60000 (54%)]	Loss: 7260.622070
#
# Test set: Average loss: 11359.1696, Accuracy: 8108/10000 (81%)
#
# Train Epoch: 5 [5300/60000 (65%)]	Loss: 5198.840820
#
# Test set: Average loss: 8653.2010, Accuracy: 7856/10000 (79%)
#
# Train Epoch: 5 [5400/60000 (76%)]	Loss: 11394.811523
#
# Test set: Average loss: 11535.7280, Accuracy: 7678/10000 (77%)
#
# Train Epoch: 5 [5500/60000 (86%)]	Loss: 26451.255859
#
# Test set: Average loss: 31753.9780, Accuracy: 7383/10000 (74%)
#
# Train Epoch: 5 [5600/60000 (97%)]	Loss: 15177.406250
#
# Test set: Average loss: 13795.1808, Accuracy: 7870/10000 (79%)
#
# Train Epoch: 6 [5700/60000 (8%)]	Loss: 9713.239258
#
# Test set: Average loss: 9711.4024, Accuracy: 8155/10000 (82%)
#
# Train Epoch: 6 [5800/60000 (18%)]	Loss: 3604.988281
#
# Test set: Average loss: 8970.1202, Accuracy: 7921/10000 (79%)
#
# Train Epoch: 6 [5900/60000 (29%)]	Loss: 11518.458984
#
# Test set: Average loss: 8582.0176, Accuracy: 7767/10000 (78%)
#
# Train Epoch: 6 [6000/60000 (40%)]	Loss: 19511.798828
#
# Test set: Average loss: 8081.4684, Accuracy: 8071/10000 (81%)
#
# Train Epoch: 6 [6100/60000 (50%)]	Loss: 16489.214844
#
# Test set: Average loss: 7192.5524, Accuracy: 8102/10000 (81%)
#
# Train Epoch: 6 [6200/60000 (61%)]	Loss: 22365.529297
#
# Test set: Average loss: 8543.7401, Accuracy: 8097/10000 (81%)
#
# Train Epoch: 6 [6300/60000 (72%)]	Loss: 2084.936523
#
# Test set: Average loss: 9730.5884, Accuracy: 7460/10000 (75%)
#
# Train Epoch: 6 [6400/60000 (82%)]	Loss: 10913.553711
#
# Test set: Average loss: 10139.3964, Accuracy: 7748/10000 (77%)
#
# Train Epoch: 6 [6500/60000 (93%)]	Loss: 10886.960938
#
# Test set: Average loss: 17337.2993, Accuracy: 7530/10000 (75%)
#
# Train Epoch: 7 [6600/60000 (4%)]	Loss: 9736.376953
#
# Test set: Average loss: 13034.4316, Accuracy: 7567/10000 (76%)
#
# Train Epoch: 7 [6700/60000 (14%)]	Loss: 7001.741699
#
# Test set: Average loss: 7616.6425, Accuracy: 7957/10000 (80%)
#
# Train Epoch: 7 [6800/60000 (25%)]	Loss: 5093.128418
#
# Test set: Average loss: 5535.4372, Accuracy: 8044/10000 (80%)
#
# Train Epoch: 7 [6900/60000 (36%)]	Loss: 15503.149414
#
# Test set: Average loss: 6650.9706, Accuracy: 7946/10000 (79%)
#
# Train Epoch: 7 [7000/60000 (46%)]	Loss: 4998.196777
#
# Test set: Average loss: 5615.2425, Accuracy: 8065/10000 (81%)
#
# Train Epoch: 7 [7100/60000 (57%)]	Loss: 8226.479492
#
# Test set: Average loss: 8529.8797, Accuracy: 7344/10000 (73%)
#
# Train Epoch: 7 [7200/60000 (68%)]	Loss: 11178.262695
#
# Test set: Average loss: 7868.7549, Accuracy: 7829/10000 (78%)
#
# Train Epoch: 7 [7300/60000 (78%)]	Loss: 3635.873779
#
# Test set: Average loss: 6972.0265, Accuracy: 7550/10000 (76%)
#
# Train Epoch: 7 [7400/60000 (89%)]	Loss: 34744.714844
#
# Test set: Average loss: 12334.8546, Accuracy: 7250/10000 (72%)
#
# Train Epoch: 7 [7500/60000 (100%)]	Loss: 2536868.000000
#
# Test set: Average loss: 1755338.1120, Accuracy: 7380/10000 (74%)
#
# Train Epoch: 8 [7600/60000 (10%)]	Loss: 84543.578125
#
# Test set: Average loss: 432120.9696, Accuracy: 7423/10000 (74%)
#
# Train Epoch: 8 [7700/60000 (21%)]	Loss: 347909.125000
#
# Test set: Average loss: 297284.0208, Accuracy: 7285/10000 (73%)
#
# Train Epoch: 8 [7800/60000 (32%)]	Loss: 387373.500000
#
# Test set: Average loss: 132398.3664, Accuracy: 7585/10000 (76%)
#
# Train Epoch: 8 [7900/60000 (42%)]	Loss: 127785.398438
#
# Test set: Average loss: 120388.5016, Accuracy: 7530/10000 (75%)
#
# Train Epoch: 8 [8000/60000 (53%)]	Loss: 511372.312500
#
# Test set: Average loss: 209552.8288, Accuracy: 7384/10000 (74%)
#
# Train Epoch: 8 [8100/60000 (64%)]	Loss: 161209.859375
#
# Test set: Average loss: 85930.7704, Accuracy: 7966/10000 (80%)
#
# Train Epoch: 8 [8200/60000 (74%)]	Loss: 105915.703125
#
# Test set: Average loss: 91961.3264, Accuracy: 7460/10000 (75%)
#
# Train Epoch: 8 [8300/60000 (85%)]	Loss: 61660.003906
#
# Test set: Average loss: 66407.4916, Accuracy: 7832/10000 (78%)
#
# Train Epoch: 8 [8400/60000 (96%)]	Loss: 103221.195312
#
# Test set: Average loss: 77742.6340, Accuracy: 7347/10000 (73%)
#
# Train Epoch: 9 [8500/60000 (6%)]	Loss: 62333.945312
#
# Test set: Average loss: 48121.5000, Accuracy: 7867/10000 (79%)
#
# Train Epoch: 9 [8600/60000 (17%)]	Loss: 68884.851562
#
# Test set: Average loss: 60519.1672, Accuracy: 7594/10000 (76%)
#
# Train Epoch: 9 [8700/60000 (28%)]	Loss: 21671.398438
#
# Test set: Average loss: 43058.5020, Accuracy: 7928/10000 (79%)
#
# Train Epoch: 9 [8800/60000 (38%)]	Loss: 48533.953125
#
# Test set: Average loss: 42571.1868, Accuracy: 7714/10000 (77%)
#
# Train Epoch: 9 [8900/60000 (49%)]	Loss: 44371.457031
#
# Test set: Average loss: 74932.4432, Accuracy: 7607/10000 (76%)
#
# Train Epoch: 9 [9000/60000 (59%)]	Loss: 40339.683594
#
# Test set: Average loss: 43507.8020, Accuracy: 7770/10000 (78%)
#
# Train Epoch: 9 [9100/60000 (70%)]	Loss: 60555.648438
#
# Test set: Average loss: 28416.9676, Accuracy: 7908/10000 (79%)
#
# Train Epoch: 9 [9200/60000 (81%)]	Loss: 51253.671875
#
# Test set: Average loss: 30535.8962, Accuracy: 7900/10000 (79%)
#
# Train Epoch: 9 [9300/60000 (91%)]	Loss: 39424.148438
#
# Test set: Average loss: 34968.5696, Accuracy: 7069/10000 (71%)
#
# Train Epoch: 10 [9400/60000 (2%)]	Loss: 19409.169922
#
# Test set: Average loss: 25593.5092, Accuracy: 7973/10000 (80%)
#
# Train Epoch: 10 [9500/60000 (13%)]	Loss: 14252.486328
#
# Test set: Average loss: 41383.9500, Accuracy: 7513/10000 (75%)
#
# Train Epoch: 10 [9600/60000 (23%)]	Loss: 21285.810547
#
# Test set: Average loss: 26775.1424, Accuracy: 7641/10000 (76%)
#
# Train Epoch: 10 [9700/60000 (34%)]	Loss: 5697.421875
#
# Test set: Average loss: 28162.4958, Accuracy: 8096/10000 (81%)
#
# Train Epoch: 10 [9800/60000 (45%)]	Loss: 26130.343750
#
# Test set: Average loss: 27383.3586, Accuracy: 7705/10000 (77%)
#
# Train Epoch: 10 [9900/60000 (55%)]	Loss: 14761.749023
#
# Test set: Average loss: 23060.7704, Accuracy: 7466/10000 (75%)
#
# Train Epoch: 10 [10000/60000 (66%)]	Loss: 29298.679688
#
# Test set: Average loss: 29653.6374, Accuracy: 7833/10000 (78%)
#
# Train Epoch: 10 [10100/60000 (77%)]	Loss: 19153.101562
#
# Test set: Average loss: 32953.5692, Accuracy: 7673/10000 (77%)
#
# Train Epoch: 10 [10200/60000 (87%)]	Loss: 133111.437500
#
# Test set: Average loss: 111174.8152, Accuracy: 7597/10000 (76%)
#
# Train Epoch: 10 [10300/60000 (98%)]	Loss: 55098.933594
#
# Test set: Average loss: 29202.4742, Accuracy: 7685/10000 (77%)
#
# Train Epoch: 11 [10400/60000 (9%)]	Loss: 19050.869141
#
# Test set: Average loss: 14865.3592, Accuracy: 7979/10000 (80%)
#
# Train Epoch: 11 [10500/60000 (19%)]	Loss: 7099.290039
#
# Test set: Average loss: 14630.3240, Accuracy: 7543/10000 (75%)
#
# Train Epoch: 11 [10600/60000 (30%)]	Loss: 65451.304688
#
# Test set: Average loss: 18496.6083, Accuracy: 8006/10000 (80%)
#
# Train Epoch: 11 [10700/60000 (41%)]	Loss: 26956.140625
#
# Test set: Average loss: 20871.3775, Accuracy: 7769/10000 (78%)
#
# Train Epoch: 11 [10800/60000 (51%)]	Loss: 22750.343750
#
# Test set: Average loss: 22874.7497, Accuracy: 8087/10000 (81%)
#
# Train Epoch: 11 [10900/60000 (62%)]	Loss: 28659.156250
#
# Test set: Average loss: 15474.5015, Accuracy: 7414/10000 (74%)
#
# Train Epoch: 11 [11000/60000 (73%)]	Loss: 18731.855469
#
# Test set: Average loss: 23657.5720, Accuracy: 7251/10000 (73%)
#
# Train Epoch: 11 [11100/60000 (83%)]	Loss: 27732.474609
#
# Test set: Average loss: 19483.4030, Accuracy: 7872/10000 (79%)
#
# Train Epoch: 11 [11200/60000 (94%)]	Loss: 25045.140625
#
# Test set: Average loss: 16298.9210, Accuracy: 7407/10000 (74%)
#
# Train Epoch: 12 [11300/60000 (5%)]	Loss: 12875.078125
#
# Test set: Average loss: 15064.4998, Accuracy: 7247/10000 (72%)
#
# Train Epoch: 12 [11400/60000 (15%)]	Loss: 7956.324219
#
# Test set: Average loss: 13885.1190, Accuracy: 7867/10000 (79%)
#
# Train Epoch: 12 [11500/60000 (26%)]	Loss: 7022.631348
#
# Test set: Average loss: 16726.8456, Accuracy: 7570/10000 (76%)
#
# Train Epoch: 12 [11600/60000 (37%)]	Loss: 16876.332031
#
# Test set: Average loss: 12978.4035, Accuracy: 8034/10000 (80%)
#
# Train Epoch: 12 [11700/60000 (47%)]	Loss: 13904.338867
#
# Test set: Average loss: 12161.0916, Accuracy: 7966/10000 (80%)
#
# Train Epoch: 12 [11800/60000 (58%)]	Loss: 9289.003906
#
# Test set: Average loss: 11848.0202, Accuracy: 7796/10000 (78%)
#
# Train Epoch: 12 [11900/60000 (69%)]	Loss: 24419.964844
#
# Test set: Average loss: 11870.9125, Accuracy: 7451/10000 (75%)
#
# Train Epoch: 12 [12000/60000 (79%)]	Loss: 19181.042969
#
# Test set: Average loss: 9035.4545, Accuracy: 8059/10000 (81%)
#
# Train Epoch: 12 [12100/60000 (90%)]	Loss: 6214.242188
#
# Test set: Average loss: 11973.6385, Accuracy: 7859/10000 (79%)
#
# Train Epoch: 13 [12200/60000 (1%)]	Loss: 3141.280273
#
# Test set: Average loss: 8892.3050, Accuracy: 7823/10000 (78%)
#
# Train Epoch: 13 [12300/60000 (11%)]	Loss: 15592.441406
#
# Test set: Average loss: 7922.1596, Accuracy: 7867/10000 (79%)
#
# Train Epoch: 13 [12400/60000 (22%)]	Loss: 6450.614258
#
# Test set: Average loss: 9831.3830, Accuracy: 7982/10000 (80%)
#
# Train Epoch: 13 [12500/60000 (33%)]	Loss: 7596.557129
#
# Test set: Average loss: 7413.1471, Accuracy: 7636/10000 (76%)
#
# Train Epoch: 13 [12600/60000 (43%)]	Loss: 6937.355469
#
# Test set: Average loss: 11731.0073, Accuracy: 7528/10000 (75%)
#
# Train Epoch: 13 [12700/60000 (54%)]	Loss: 4629.126953
#
# Test set: Average loss: 13227.2086, Accuracy: 7538/10000 (75%)
#
# Train Epoch: 13 [12800/60000 (65%)]	Loss: 20064.285156
#
# Test set: Average loss: 23997.6726, Accuracy: 7387/10000 (74%)
#
# Train Epoch: 13 [12900/60000 (75%)]	Loss: 5779.839844
#
# Test set: Average loss: 12647.5734, Accuracy: 8127/10000 (81%)
#
# Train Epoch: 13 [13000/60000 (86%)]	Loss: 4192.945312
#
# Test set: Average loss: 10079.9677, Accuracy: 7901/10000 (79%)
#
# Train Epoch: 13 [13100/60000 (97%)]	Loss: 6651.821289
#
# Test set: Average loss: 7056.2166, Accuracy: 8122/10000 (81%)

# %% [markdown]
# ## 0.2 Play with parameters.(3pt)
# How many trainable parameters does the trained model have? The answer needs to depend on the input `model` - outputting a constant number will not get any credits. Hint: Find out how to use model.parameters() in PyTorch.

# %%
def param_count(model):
    params = []
    for param in model.parameters(): # checking number of learned parameters
        params.append(param.numel())
    return sum(params)

print('Model has {} params'.format(param_count(model)))
# Out:
# Model has 454922 params

# %% [markdown]
# ## 0.3 Deep Linear Networks?!? (5pt)
# Until this point, there are no non-linearities in the SimpleCNN! (Your TAs were just as surprised as you are at the results.) Your next task is to modify `simple_cnn.py` to add non-linear activation layers, and train your model in full scale. Make sure to add non-linearities at **every** applicable layer.
#
# Compute the loss and accuracy curves on train and test sets after 5 epochs. The accuracy should be around 90% or higher.

# %%
args.epochs = 5
main()
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.316709
#
# Test set: Average loss: 2.2411, Accuracy: 1487/10000 (15%)
#
# Train Epoch: 0 [100/60000 (11%)]	Loss: 0.713661
#
# Test set: Average loss: 0.6394, Accuracy: 7588/10000 (76%)
#
# Train Epoch: 0 [200/60000 (21%)]	Loss: 0.742926
#
# Test set: Average loss: 0.5443, Accuracy: 8026/10000 (80%)
#
# Train Epoch: 0 [300/60000 (32%)]	Loss: 0.332849
#
# Test set: Average loss: 0.4569, Accuracy: 8286/10000 (83%)
#
# Train Epoch: 0 [400/60000 (43%)]	Loss: 0.302382
#
# Test set: Average loss: 0.4227, Accuracy: 8454/10000 (85%)
#
# Train Epoch: 0 [500/60000 (53%)]	Loss: 0.502598
#
# Test set: Average loss: 0.4040, Accuracy: 8526/10000 (85%)
#
# Train Epoch: 0 [600/60000 (64%)]	Loss: 0.495779
#
# Test set: Average loss: 0.3644, Accuracy: 8683/10000 (87%)
#
# Train Epoch: 0 [700/60000 (75%)]	Loss: 0.358350
#
# Test set: Average loss: 0.3707, Accuracy: 8637/10000 (86%)
#
# Train Epoch: 0 [800/60000 (85%)]	Loss: 0.388437
#
# Test set: Average loss: 0.3485, Accuracy: 8738/10000 (87%)
#
# Train Epoch: 0 [900/60000 (96%)]	Loss: 0.454682
#
# Test set: Average loss: 0.3517, Accuracy: 8730/10000 (87%)
#
# Train Epoch: 1 [1000/60000 (7%)]	Loss: 0.336023
#
# Test set: Average loss: 0.3127, Accuracy: 8855/10000 (89%)
#
# Train Epoch: 1 [1100/60000 (17%)]	Loss: 0.176968
#
# Test set: Average loss: 0.3180, Accuracy: 8847/10000 (88%)
#
# Train Epoch: 1 [1200/60000 (28%)]	Loss: 0.339229
#
# Test set: Average loss: 0.3228, Accuracy: 8812/10000 (88%)
#
# Train Epoch: 1 [1300/60000 (39%)]	Loss: 0.307976
#
# Test set: Average loss: 0.3137, Accuracy: 8856/10000 (89%)
#
# Train Epoch: 1 [1400/60000 (49%)]	Loss: 0.321531
#
# Test set: Average loss: 0.3249, Accuracy: 8794/10000 (88%)
#
# Train Epoch: 1 [1500/60000 (60%)]	Loss: 0.385911
#
# Test set: Average loss: 0.3048, Accuracy: 8908/10000 (89%)
#
# Train Epoch: 1 [1600/60000 (71%)]	Loss: 0.315035
#
# Test set: Average loss: 0.2916, Accuracy: 8930/10000 (89%)
#
# Train Epoch: 1 [1700/60000 (81%)]	Loss: 0.298756
#
# Test set: Average loss: 0.2939, Accuracy: 8943/10000 (89%)
#
# Train Epoch: 1 [1800/60000 (92%)]	Loss: 0.159378
#
# Test set: Average loss: 0.2907, Accuracy: 8923/10000 (89%)
#
# Train Epoch: 2 [1900/60000 (3%)]	Loss: 0.204322
#
# Test set: Average loss: 0.2844, Accuracy: 8964/10000 (90%)
#
# Train Epoch: 2 [2000/60000 (13%)]	Loss: 0.263602
#
# Test set: Average loss: 0.2813, Accuracy: 8990/10000 (90%)
#
# Train Epoch: 2 [2100/60000 (24%)]	Loss: 0.345935
#
# Test set: Average loss: 0.2856, Accuracy: 8955/10000 (90%)
#
# Train Epoch: 2 [2200/60000 (35%)]	Loss: 0.290918
#
# Test set: Average loss: 0.2745, Accuracy: 8988/10000 (90%)
#
# Train Epoch: 2 [2300/60000 (45%)]	Loss: 0.208210
#
# Test set: Average loss: 0.2827, Accuracy: 8975/10000 (90%)
#
# Train Epoch: 2 [2400/60000 (56%)]	Loss: 0.142815
#
# Test set: Average loss: 0.2904, Accuracy: 8927/10000 (89%)
#
# Train Epoch: 2 [2500/60000 (67%)]	Loss: 0.446402
#
# Test set: Average loss: 0.2683, Accuracy: 9023/10000 (90%)
#
# Train Epoch: 2 [2600/60000 (77%)]	Loss: 0.265129
#
# Test set: Average loss: 0.2693, Accuracy: 9030/10000 (90%)
#
# Train Epoch: 2 [2700/60000 (88%)]	Loss: 0.143903
#
# Test set: Average loss: 0.2748, Accuracy: 9003/10000 (90%)
#
# Train Epoch: 2 [2800/60000 (99%)]	Loss: 0.377113
#
# Test set: Average loss: 0.2843, Accuracy: 8963/10000 (90%)
#
# Train Epoch: 3 [2900/60000 (9%)]	Loss: 0.181111
#
# Test set: Average loss: 0.2592, Accuracy: 9062/10000 (91%)
#
# Train Epoch: 3 [3000/60000 (20%)]	Loss: 0.227848
#
# Test set: Average loss: 0.2567, Accuracy: 9069/10000 (91%)
#
# Train Epoch: 3 [3100/60000 (30%)]	Loss: 0.283829
#
# Test set: Average loss: 0.2558, Accuracy: 9070/10000 (91%)
#
# Train Epoch: 3 [3200/60000 (41%)]	Loss: 0.160839
#
# Test set: Average loss: 0.2532, Accuracy: 9102/10000 (91%)
#
# Train Epoch: 3 [3300/60000 (52%)]	Loss: 0.154971
#
# Test set: Average loss: 0.2573, Accuracy: 9063/10000 (91%)
#
# Train Epoch: 3 [3400/60000 (62%)]	Loss: 0.395956
#
# Test set: Average loss: 0.2468, Accuracy: 9110/10000 (91%)
#
# Train Epoch: 3 [3500/60000 (73%)]	Loss: 0.181368
#
# Test set: Average loss: 0.2588, Accuracy: 9059/10000 (91%)
#
# Train Epoch: 3 [3600/60000 (84%)]	Loss: 0.246464
#
# Test set: Average loss: 0.2532, Accuracy: 9093/10000 (91%)
#
# Train Epoch: 3 [3700/60000 (94%)]	Loss: 0.242790
#
# Test set: Average loss: 0.2486, Accuracy: 9085/10000 (91%)
#
# Train Epoch: 4 [3800/60000 (5%)]	Loss: 0.209371
#
# Test set: Average loss: 0.2475, Accuracy: 9114/10000 (91%)
#
# Train Epoch: 4 [3900/60000 (16%)]	Loss: 0.126900
#
# Test set: Average loss: 0.2460, Accuracy: 9093/10000 (91%)
#
# Train Epoch: 4 [4000/60000 (26%)]	Loss: 0.151121
#
# Test set: Average loss: 0.2469, Accuracy: 9110/10000 (91%)
#
# Train Epoch: 4 [4100/60000 (37%)]	Loss: 0.135448
#
# Test set: Average loss: 0.2453, Accuracy: 9118/10000 (91%)
#
# Train Epoch: 4 [4200/60000 (48%)]	Loss: 0.232541
#
# Test set: Average loss: 0.2442, Accuracy: 9127/10000 (91%)
#
# Train Epoch: 4 [4300/60000 (58%)]	Loss: 0.085414
#
# Test set: Average loss: 0.2450, Accuracy: 9105/10000 (91%)
#
# Train Epoch: 4 [4400/60000 (69%)]	Loss: 0.237122
#
# Test set: Average loss: 0.2474, Accuracy: 9091/10000 (91%)
#
# Train Epoch: 4 [4500/60000 (80%)]	Loss: 0.164106
#
# Test set: Average loss: 0.2404, Accuracy: 9120/10000 (91%)
#
# Train Epoch: 4 [4600/60000 (90%)]	Loss: 0.332437
#
# Test set: Average loss: 0.2408, Accuracy: 9136/10000 (91%)
# SimpleCNN(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (nonlinear): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (pool2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc1): Sequential(
#     (0): Linear(in_features=3136, out_features=128, bias=True)
#     (1): ReLU()
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# Where did you add your non-linearities?
#
# **YOUR ANSWER HERE**
#
#
# <br><br><br>
# Provide some insights on why the results was fairly good even without activation layers. (**2** pts)
#
# **YOUR ANSWER HERE**
