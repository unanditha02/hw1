# %% [markdown]
# # Task 0: Fashion MNIST classification in Pytorch (10 points)
#
# The goal of this task is to get you familiar with [Pytorch](https://pytorch.org/), teach you to debug your models, and give you a general understanding of deep learning and computer vision work-flows.
#
# [Fashion MNIST](https://github.com/zalandoresearch/fashion-mnist) is a dataset of [Zalando’s](https://jobs.zalando.com/tech/) article images — consisting of 70,000 grayscale images in 10
# categories. Each example is a 28x28 grayscale image, associated with a label from 10 classes. ‘Fashion-
# MNIST’ is intended to serve as a direct **drop-in replacement** for the original [MNIST](http://yann.lecun.com/exdb/mnist/) dataset — often
# used as the “Hello, World” of machine learning programs for computer vision. It shares the same image
# size and structure of training and testing splits. We will use 60,000 images to train the network and
# 10,000 images to evaluate how accurately the network learned to classify images.

# %% [markdown]
# ### Prerequisites:
#
# - Install [conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/index.html) and create a conda environment to manage all the packages for the homeworks.
# - Install the following packages in your conda environment:
#     - [jupyterlab](https://jupyter.org/install) and get familiar with basic operations on jupyter notebook.
#     - [Pytorch](https://pytorch.org/)
#     - matplotlib
#     - tensorboard
#     - imageio
#     - sklearn

# %%
# installation directions can be found on pytorch's webpage
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
# %matplotlib inline

# import our network module from simple_cnn.py
from simple_cnn import SimpleCNN              # be sure to modify or you may have to restart kernel!

# %% [markdown]
# Usually you'll parse arguments using `argparse` (or similar library) but we can simply use a stand-in object for ipython notebooks. Furthermore, PyTorch can do computations on NVidia `GPU`s or on normal `CPU`s. You can configure the setting using the `device` variable.

# %%
class ARGS(object):
    # input batch size for training 
    batch_size = 64
    # input batch size for testing
    test_batch_size=1000
    # number of epochs to train for
    epochs = 14
    # learning rate
    lr = 1e-3
    # Learning rate step gamma
    gamma = 0.7
    # how many batches to wait before logging training status
    log_every = 100
    # how many batches to wait before evaluating model
    val_every = 100
    # set true if using GPU during training
    use_cuda = False

args = ARGS()
device = torch.device("cuda" if args.use_cuda else "cpu")

# %% [markdown]
# We define some basic testing and training code. The testing code prints out the average test loss and the training code (`main`) plots train/test losses and returns the final model.

# %%
def test(model, device, test_loader):
    """Evaluate model on test dataset."""
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()
            pred = output.argmax(dim=1, keepdim=True) 
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

    return test_loss, correct / len(test_loader.dataset)

def main():
    # 1. load dataset and build dataloader
    train_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST('../data', train=True, download=True,
                       transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=args.batch_size, shuffle=True)
    test_loader = torch.utils.data.DataLoader(
        datasets.FashionMNIST('../data', train=False, transform=transforms.Compose([
                           transforms.ToTensor(),
                           transforms.Normalize((0.1307,), (0.3081,))
                       ])),
        batch_size=args.test_batch_size, shuffle=True)

    # 2. define the model, and optimizer.
    model = SimpleCNN().to(device)
    model.train()
    optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)

    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=args.gamma)
    cnt = 0
    train_log = {'iter': [], 'loss': [], 'accuracy': []}
    test_log = {'iter': [], 'loss': [], 'accuracy': []}
    correct=0
    for epoch in range(args.epochs):
        
        for batch_idx, (data, target) in enumerate(train_loader):
            
            # Get a batch of data
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()
            # Forward pass
            output = model(data)
            # Calculate the loss
            loss = F.cross_entropy(output, target)          
            # Calculate gradient w.r.t the loss
            loss.backward()
            # Optimizer takes one step
            optimizer.step()
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            train_acc = correct/(args.batch_size*(cnt+1))
            # Log info
            if cnt % args.log_every == 0:
                print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                    epoch, cnt, len(train_loader.dataset),
                           100. * batch_idx / len(train_loader), loss.item()))
                train_log['iter'].append(cnt)
                train_log['loss'].append(loss.cpu().detach().numpy())
                # TODO: q0.1 calculate your train accuracy
                train_log['accuracy'].append(train_acc)
            # Validation iteration
            if cnt % args.val_every == 0:
                test_loss, test_acc = test(model, device, test_loader)
                test_log['iter'].append(cnt)
                test_log['loss'].append(test_loss)
                test_log['accuracy'].append(test_acc)
                model.train()
            cnt += 1
        scheduler.step()
    fig = plt.figure()
    plt.plot(train_log['iter'], train_log['loss'], 'r', label='Training')
    plt.plot(test_log['iter'], test_log['loss'], 'b', label='Testing')
    plt.title('Loss')
    plt.legend()
    fig = plt.figure()
    plt.plot(train_log['iter'], train_log['accuracy'], 'r', label='Training')
    plt.plot(test_log['iter'], test_log['accuracy'], 'b', label='Testing')
    plt.title('Accuracy')
    plt.legend()
    plt.show()
    return model

# %% [markdown]
# ## 0.1 Bug Fix and Hyper-parameter search. (2pts)
#
# Simply running `main` will result in a `RuntimeError`!
# - (1 pt) Check out `TODO: q0.1` in  `simple_cnn.py` and see if you can fix the bug. You may have to restart your ipython kernel for changes to reflect in the notebook.
# - (1 pt) Fill in the `TODO: q0.1` in the `main()` function above to calculated the train accuracy.
#
#
# Once you fix the bugs, you should be able to get a reasonable accuracy (>80%) within 100 iterations just by tuning some hyper-parameter. Include the train/test plots of your best hyperparamter setting and comment on why you think these settings worked best. (you can complete this task on CPU)
#
# **YOUR ANSWER HERE**

# %%
#### FEEL FREE TO MODIFY args VARIABLE HERE OR ABOVE ####
# args.gamma = float('inf')
args.use_cuda = True

# DON'T CHANGE
# prints out arguments and runs main
for attr in dir(args):
    if '__' not in attr and attr !='use_cuda':
        print('args.{} = {}'.format(attr, getattr(args, attr)))
print('\n\n')
model = main()
# Out:
# args.batch_size = 64
# args.epochs = 14
# args.gamma = 0.7
# args.log_every = 100
# args.lr = 0.001
# args.test_batch_size = 1000
# args.val_every = 100
#
#
#
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.330482
#
# Test set: Average loss: 1.9254, Accuracy: 3525/10000 (35%)
#
# Train Epoch: 0 [100/60000 (11%)]	Loss: 0.655022
#
# Test set: Average loss: 0.6599, Accuracy: 7596/10000 (76%)
#
# Train Epoch: 0 [200/60000 (21%)]	Loss: 0.514588
#
# Test set: Average loss: 0.5718, Accuracy: 7962/10000 (80%)
#
# Train Epoch: 0 [300/60000 (32%)]	Loss: 0.405650
#
# Test set: Average loss: 0.5406, Accuracy: 8120/10000 (81%)
#
# Train Epoch: 0 [400/60000 (43%)]	Loss: 0.501964
#
# Test set: Average loss: 0.5302, Accuracy: 8168/10000 (82%)
#
# Train Epoch: 0 [500/60000 (53%)]	Loss: 0.479049
#
# Test set: Average loss: 0.5399, Accuracy: 8005/10000 (80%)
#
# Train Epoch: 0 [600/60000 (64%)]	Loss: 0.539675
#
# Test set: Average loss: 0.5090, Accuracy: 8256/10000 (83%)
#
# Train Epoch: 0 [700/60000 (75%)]	Loss: 0.367375
#
# Test set: Average loss: 0.5206, Accuracy: 8155/10000 (82%)
#
# Train Epoch: 0 [800/60000 (85%)]	Loss: 0.464354
#
# Test set: Average loss: 0.5106, Accuracy: 8181/10000 (82%)
#
# Train Epoch: 0 [900/60000 (96%)]	Loss: 0.350068
#
# Test set: Average loss: 0.5016, Accuracy: 8263/10000 (83%)
#
# Train Epoch: 1 [1000/60000 (7%)]	Loss: 0.403542
#
# Test set: Average loss: 0.4911, Accuracy: 8260/10000 (83%)
#
# Train Epoch: 1 [1100/60000 (17%)]	Loss: 0.498644
#
# Test set: Average loss: 0.4880, Accuracy: 8268/10000 (83%)
#
# Train Epoch: 1 [1200/60000 (28%)]	Loss: 0.336857
#
# Test set: Average loss: 0.5151, Accuracy: 8173/10000 (82%)
#
# Train Epoch: 1 [1300/60000 (39%)]	Loss: 0.383548
#
# Test set: Average loss: 0.4923, Accuracy: 8267/10000 (83%)
#
# Train Epoch: 1 [1400/60000 (49%)]	Loss: 0.300166
#
# Test set: Average loss: 0.5088, Accuracy: 8262/10000 (83%)
#
# Train Epoch: 1 [1500/60000 (60%)]	Loss: 0.467317
#
# Test set: Average loss: 0.4832, Accuracy: 8293/10000 (83%)
#
# Train Epoch: 1 [1600/60000 (71%)]	Loss: 0.421241
#
# Test set: Average loss: 0.4800, Accuracy: 8314/10000 (83%)
#
# Train Epoch: 1 [1700/60000 (81%)]	Loss: 0.474102
#
# Test set: Average loss: 0.4794, Accuracy: 8329/10000 (83%)
#
# Train Epoch: 1 [1800/60000 (92%)]	Loss: 0.331719
#
# Test set: Average loss: 0.4758, Accuracy: 8299/10000 (83%)
#
# Train Epoch: 2 [1900/60000 (3%)]	Loss: 0.505885
#
# Test set: Average loss: 0.4728, Accuracy: 8381/10000 (84%)
#
# Train Epoch: 2 [2000/60000 (13%)]	Loss: 0.511152
#
# Test set: Average loss: 0.4657, Accuracy: 8365/10000 (84%)
#
# Train Epoch: 2 [2100/60000 (24%)]	Loss: 0.445572
#
# Test set: Average loss: 0.4756, Accuracy: 8340/10000 (83%)
#
# Train Epoch: 2 [2200/60000 (35%)]	Loss: 0.435922
#
# Test set: Average loss: 0.4697, Accuracy: 8340/10000 (83%)
#
# Train Epoch: 2 [2300/60000 (45%)]	Loss: 0.531414
#
# Test set: Average loss: 0.4698, Accuracy: 8361/10000 (84%)
#
# Train Epoch: 2 [2400/60000 (56%)]	Loss: 0.305229
#
# Test set: Average loss: 0.4742, Accuracy: 8355/10000 (84%)
#
# Train Epoch: 2 [2500/60000 (67%)]	Loss: 0.465507
#
# Test set: Average loss: 0.4804, Accuracy: 8306/10000 (83%)
#
# Train Epoch: 2 [2600/60000 (77%)]	Loss: 0.289898
#
# Test set: Average loss: 0.4698, Accuracy: 8335/10000 (83%)
#
# Train Epoch: 2 [2700/60000 (88%)]	Loss: 0.552764
#
# Test set: Average loss: 0.4661, Accuracy: 8351/10000 (84%)
#
# Train Epoch: 2 [2800/60000 (99%)]	Loss: 0.323293
#
# Test set: Average loss: 0.4632, Accuracy: 8405/10000 (84%)
#
# Train Epoch: 3 [2900/60000 (9%)]	Loss: 0.441985
#
# Test set: Average loss: 0.4692, Accuracy: 8322/10000 (83%)
#
# Train Epoch: 3 [3000/60000 (20%)]	Loss: 0.563917
#
# Test set: Average loss: 0.4612, Accuracy: 8390/10000 (84%)
#
# Train Epoch: 3 [3100/60000 (30%)]	Loss: 0.597562
#
# Test set: Average loss: 0.4578, Accuracy: 8383/10000 (84%)
#
# Train Epoch: 3 [3200/60000 (41%)]	Loss: 0.369846
#
# Test set: Average loss: 0.4596, Accuracy: 8394/10000 (84%)
#
# Train Epoch: 3 [3300/60000 (52%)]	Loss: 0.408976
#
# Test set: Average loss: 0.4526, Accuracy: 8426/10000 (84%)
#
# Train Epoch: 3 [3400/60000 (62%)]	Loss: 0.288650
#
# Test set: Average loss: 0.4584, Accuracy: 8382/10000 (84%)
#
# Train Epoch: 3 [3500/60000 (73%)]	Loss: 0.484151
#
# Test set: Average loss: 0.4598, Accuracy: 8390/10000 (84%)
#
# Train Epoch: 3 [3600/60000 (84%)]	Loss: 0.374013
#
# Test set: Average loss: 0.4643, Accuracy: 8354/10000 (84%)
#
# Train Epoch: 3 [3700/60000 (94%)]	Loss: 0.479939
#
# Test set: Average loss: 0.4584, Accuracy: 8396/10000 (84%)
#
# Train Epoch: 4 [3800/60000 (5%)]	Loss: 0.410520
#
# Test set: Average loss: 0.4541, Accuracy: 8376/10000 (84%)
#
# Train Epoch: 4 [3900/60000 (16%)]	Loss: 0.385548
#
# Test set: Average loss: 0.4536, Accuracy: 8412/10000 (84%)
#
# Train Epoch: 4 [4000/60000 (26%)]	Loss: 0.328597
#
# Test set: Average loss: 0.4548, Accuracy: 8406/10000 (84%)
#
# Train Epoch: 4 [4100/60000 (37%)]	Loss: 0.662470
#
# Test set: Average loss: 0.4498, Accuracy: 8438/10000 (84%)
#
# Train Epoch: 4 [4200/60000 (48%)]	Loss: 0.442807
#
# Test set: Average loss: 0.4550, Accuracy: 8405/10000 (84%)
#
# Train Epoch: 4 [4300/60000 (58%)]	Loss: 0.463190
#
# Test set: Average loss: 0.4493, Accuracy: 8411/10000 (84%)
#
# Train Epoch: 4 [4400/60000 (69%)]	Loss: 0.581552
#
# Test set: Average loss: 0.4478, Accuracy: 8424/10000 (84%)
#
# Train Epoch: 4 [4500/60000 (80%)]	Loss: 0.400632
#
# Test set: Average loss: 0.4506, Accuracy: 8413/10000 (84%)
#
# Train Epoch: 4 [4600/60000 (90%)]	Loss: 0.216483
#
# Test set: Average loss: 0.4524, Accuracy: 8411/10000 (84%)
#
# Train Epoch: 5 [4700/60000 (1%)]	Loss: 0.202250
#
# Test set: Average loss: 0.4482, Accuracy: 8420/10000 (84%)
#
# Train Epoch: 5 [4800/60000 (12%)]	Loss: 0.249471
#
# Test set: Average loss: 0.4470, Accuracy: 8410/10000 (84%)
#
# Train Epoch: 5 [4900/60000 (22%)]	Loss: 0.442181
#
# Test set: Average loss: 0.4479, Accuracy: 8400/10000 (84%)
#
# Train Epoch: 5 [5000/60000 (33%)]	Loss: 0.280168
#
# Test set: Average loss: 0.4487, Accuracy: 8415/10000 (84%)
#
# Train Epoch: 5 [5100/60000 (44%)]	Loss: 0.237186
#
# Test set: Average loss: 0.4528, Accuracy: 8390/10000 (84%)
#
# Train Epoch: 5 [5200/60000 (54%)]	Loss: 0.370970
#
# Test set: Average loss: 0.4488, Accuracy: 8422/10000 (84%)
#
# Train Epoch: 5 [5300/60000 (65%)]	Loss: 0.249544
#
# Test set: Average loss: 0.4519, Accuracy: 8430/10000 (84%)
#
# Train Epoch: 5 [5400/60000 (76%)]	Loss: 0.474626
#
# Test set: Average loss: 0.4460, Accuracy: 8443/10000 (84%)
#
# Train Epoch: 5 [5500/60000 (86%)]	Loss: 0.146188
#
# Test set: Average loss: 0.4442, Accuracy: 8440/10000 (84%)
#
# Train Epoch: 5 [5600/60000 (97%)]	Loss: 0.456175
#
# Test set: Average loss: 0.4429, Accuracy: 8429/10000 (84%)
#
# Train Epoch: 6 [5700/60000 (8%)]	Loss: 0.307003
#
# Test set: Average loss: 0.4466, Accuracy: 8412/10000 (84%)
#
# Train Epoch: 6 [5800/60000 (18%)]	Loss: 0.400255
#
# Test set: Average loss: 0.4440, Accuracy: 8425/10000 (84%)
#
# Train Epoch: 6 [5900/60000 (29%)]	Loss: 0.195025
#
# Test set: Average loss: 0.4448, Accuracy: 8423/10000 (84%)
#
# Train Epoch: 6 [6000/60000 (40%)]	Loss: 0.419841
#
# Test set: Average loss: 0.4446, Accuracy: 8425/10000 (84%)
#
# Train Epoch: 6 [6100/60000 (50%)]	Loss: 0.224004
#
# Test set: Average loss: 0.4458, Accuracy: 8433/10000 (84%)
#
# Train Epoch: 6 [6200/60000 (61%)]	Loss: 0.302633
#
# Test set: Average loss: 0.4461, Accuracy: 8429/10000 (84%)
#
# Train Epoch: 6 [6300/60000 (72%)]	Loss: 0.274306
#
# Test set: Average loss: 0.4439, Accuracy: 8435/10000 (84%)
#
# Train Epoch: 6 [6400/60000 (82%)]	Loss: 0.388024
#
# Test set: Average loss: 0.4485, Accuracy: 8436/10000 (84%)
#
# Train Epoch: 6 [6500/60000 (93%)]	Loss: 0.330586
#
# Test set: Average loss: 0.4412, Accuracy: 8446/10000 (84%)
#
# Train Epoch: 7 [6600/60000 (4%)]	Loss: 0.357392
#
# Test set: Average loss: 0.4409, Accuracy: 8415/10000 (84%)
#
# Train Epoch: 7 [6700/60000 (14%)]	Loss: 0.260779
#
# Test set: Average loss: 0.4414, Accuracy: 8434/10000 (84%)
#
# Train Epoch: 7 [6800/60000 (25%)]	Loss: 0.418537
#
# Test set: Average loss: 0.4423, Accuracy: 8404/10000 (84%)
#
# Train Epoch: 7 [6900/60000 (36%)]	Loss: 0.519453
#
# Test set: Average loss: 0.4428, Accuracy: 8422/10000 (84%)
#
# Train Epoch: 7 [7000/60000 (46%)]	Loss: 0.521825
#
# Test set: Average loss: 0.4436, Accuracy: 8417/10000 (84%)
#
# Train Epoch: 7 [7100/60000 (57%)]	Loss: 0.365672
#
# Test set: Average loss: 0.4407, Accuracy: 8437/10000 (84%)
#
# Train Epoch: 7 [7200/60000 (68%)]	Loss: 0.406780
#
# Test set: Average loss: 0.4415, Accuracy: 8442/10000 (84%)
#
# Train Epoch: 7 [7300/60000 (78%)]	Loss: 0.516483
#
# Test set: Average loss: 0.4407, Accuracy: 8442/10000 (84%)
#
# Train Epoch: 7 [7400/60000 (89%)]	Loss: 0.282541
#
# Test set: Average loss: 0.4451, Accuracy: 8441/10000 (84%)
#
# Train Epoch: 7 [7500/60000 (100%)]	Loss: 0.434409
#
# Test set: Average loss: 0.4438, Accuracy: 8447/10000 (84%)
#
# Train Epoch: 8 [7600/60000 (10%)]	Loss: 0.371112
#
# Test set: Average loss: 0.4402, Accuracy: 8449/10000 (84%)
#
# Train Epoch: 8 [7700/60000 (21%)]	Loss: 0.295192
#
# Test set: Average loss: 0.4414, Accuracy: 8445/10000 (84%)
#
# Train Epoch: 8 [7800/60000 (32%)]	Loss: 0.354997
#
# Test set: Average loss: 0.4415, Accuracy: 8453/10000 (85%)
#
# Train Epoch: 8 [7900/60000 (42%)]	Loss: 0.334916
#
# Test set: Average loss: 0.4436, Accuracy: 8435/10000 (84%)
#
# Train Epoch: 8 [8000/60000 (53%)]	Loss: 0.356046
#
# Test set: Average loss: 0.4396, Accuracy: 8435/10000 (84%)
#
# Train Epoch: 8 [8100/60000 (64%)]	Loss: 0.255044
#
# Test set: Average loss: 0.4417, Accuracy: 8431/10000 (84%)
#
# Train Epoch: 8 [8200/60000 (74%)]	Loss: 0.329004
#
# Test set: Average loss: 0.4427, Accuracy: 8436/10000 (84%)
#
# Train Epoch: 8 [8300/60000 (85%)]	Loss: 0.674518
#
# Test set: Average loss: 0.4397, Accuracy: 8445/10000 (84%)
#
# Train Epoch: 8 [8400/60000 (96%)]	Loss: 0.353396
#
# Test set: Average loss: 0.4402, Accuracy: 8446/10000 (84%)
#
# Train Epoch: 9 [8500/60000 (6%)]	Loss: 0.344654
#
# Test set: Average loss: 0.4412, Accuracy: 8421/10000 (84%)
#
# Train Epoch: 9 [8600/60000 (17%)]	Loss: 0.253102
#
# Test set: Average loss: 0.4395, Accuracy: 8441/10000 (84%)
#
# Train Epoch: 9 [8700/60000 (28%)]	Loss: 0.461224
#
# Test set: Average loss: 0.4400, Accuracy: 8436/10000 (84%)
#
# Train Epoch: 9 [8800/60000 (38%)]	Loss: 0.519964
#
# Test set: Average loss: 0.4414, Accuracy: 8452/10000 (85%)
#
# Train Epoch: 9 [8900/60000 (49%)]	Loss: 0.277820
#
# Test set: Average loss: 0.4401, Accuracy: 8439/10000 (84%)
#
# Train Epoch: 9 [9000/60000 (59%)]	Loss: 0.472575
#
# Test set: Average loss: 0.4406, Accuracy: 8455/10000 (85%)
#
# Train Epoch: 9 [9100/60000 (70%)]	Loss: 0.195773
#
# Test set: Average loss: 0.4394, Accuracy: 8448/10000 (84%)
#
# Train Epoch: 9 [9200/60000 (81%)]	Loss: 0.507436
#
# Test set: Average loss: 0.4394, Accuracy: 8449/10000 (84%)
#
# Train Epoch: 9 [9300/60000 (91%)]	Loss: 0.336368
#
# Test set: Average loss: 0.4397, Accuracy: 8451/10000 (85%)
#
# Train Epoch: 10 [9400/60000 (2%)]	Loss: 0.424798
#
# Test set: Average loss: 0.4399, Accuracy: 8443/10000 (84%)
#
# Train Epoch: 10 [9500/60000 (13%)]	Loss: 0.516548
#
# Test set: Average loss: 0.4398, Accuracy: 8430/10000 (84%)
#
# Train Epoch: 10 [9600/60000 (23%)]	Loss: 0.285983
#
# Test set: Average loss: 0.4391, Accuracy: 8446/10000 (84%)
#
# Train Epoch: 10 [9700/60000 (34%)]	Loss: 0.347207
#
# Test set: Average loss: 0.4398, Accuracy: 8444/10000 (84%)
#
# Train Epoch: 10 [9800/60000 (45%)]	Loss: 0.469477
#
# Test set: Average loss: 0.4398, Accuracy: 8451/10000 (85%)
#
# Train Epoch: 10 [9900/60000 (55%)]	Loss: 0.401652
#
# Test set: Average loss: 0.4396, Accuracy: 8444/10000 (84%)
#
# Train Epoch: 10 [10000/60000 (66%)]	Loss: 0.321934
#
# Test set: Average loss: 0.4405, Accuracy: 8446/10000 (84%)
#
# Train Epoch: 10 [10100/60000 (77%)]	Loss: 0.288014
#
# Test set: Average loss: 0.4397, Accuracy: 8454/10000 (85%)
#
# Train Epoch: 10 [10200/60000 (87%)]	Loss: 0.728317
#
# Test set: Average loss: 0.4400, Accuracy: 8450/10000 (84%)
#
# Train Epoch: 10 [10300/60000 (98%)]	Loss: 0.402448
#
# Test set: Average loss: 0.4397, Accuracy: 8443/10000 (84%)
#
# Train Epoch: 11 [10400/60000 (9%)]	Loss: 0.426118
#
# Test set: Average loss: 0.4388, Accuracy: 8452/10000 (85%)
#
# Train Epoch: 11 [10500/60000 (19%)]	Loss: 0.312702
#
# Test set: Average loss: 0.4398, Accuracy: 8448/10000 (84%)
#
# Train Epoch: 11 [10600/60000 (30%)]	Loss: 0.369233
#
# Test set: Average loss: 0.4392, Accuracy: 8445/10000 (84%)
#
# Train Epoch: 11 [10700/60000 (41%)]	Loss: 0.310454
#
# Test set: Average loss: 0.4400, Accuracy: 8452/10000 (85%)
#
# Train Epoch: 11 [10800/60000 (51%)]	Loss: 0.448860
#
# Test set: Average loss: 0.4392, Accuracy: 8446/10000 (84%)
#
# Train Epoch: 11 [10900/60000 (62%)]	Loss: 0.502730
#
# Test set: Average loss: 0.4393, Accuracy: 8448/10000 (84%)
#
# Train Epoch: 11 [11000/60000 (73%)]	Loss: 0.380040
#
# Test set: Average loss: 0.4394, Accuracy: 8450/10000 (84%)
#
# Train Epoch: 11 [11100/60000 (83%)]	Loss: 0.425510
#
# Test set: Average loss: 0.4393, Accuracy: 8446/10000 (84%)
#
# Train Epoch: 11 [11200/60000 (94%)]	Loss: 0.586691
#
# Test set: Average loss: 0.4393, Accuracy: 8447/10000 (84%)
#
# Train Epoch: 12 [11300/60000 (5%)]	Loss: 0.377601
#
# Test set: Average loss: 0.4386, Accuracy: 8447/10000 (84%)
#
# Train Epoch: 12 [11400/60000 (15%)]	Loss: 0.287936
#
# Test set: Average loss: 0.4386, Accuracy: 8450/10000 (84%)
#
# Train Epoch: 12 [11500/60000 (26%)]	Loss: 0.605226
#
# Test set: Average loss: 0.4388, Accuracy: 8437/10000 (84%)
#
# Train Epoch: 12 [11600/60000 (37%)]	Loss: 0.427129
#
# Test set: Average loss: 0.4389, Accuracy: 8446/10000 (84%)
#
# Train Epoch: 12 [11700/60000 (47%)]	Loss: 0.237583
#
# Test set: Average loss: 0.4389, Accuracy: 8458/10000 (85%)
#
# Train Epoch: 12 [11800/60000 (58%)]	Loss: 0.331700
#
# Test set: Average loss: 0.4391, Accuracy: 8456/10000 (85%)
#
# Train Epoch: 12 [11900/60000 (69%)]	Loss: 0.224012
#
# Test set: Average loss: 0.4393, Accuracy: 8449/10000 (84%)
#
# Train Epoch: 12 [12000/60000 (79%)]	Loss: 0.270425
#
# Test set: Average loss: 0.4393, Accuracy: 8450/10000 (84%)
#
# Train Epoch: 12 [12100/60000 (90%)]	Loss: 0.384256
#
# Test set: Average loss: 0.4383, Accuracy: 8449/10000 (84%)
#
# Train Epoch: 13 [12200/60000 (1%)]	Loss: 0.418485
#
# Test set: Average loss: 0.4384, Accuracy: 8445/10000 (84%)
#
# Train Epoch: 13 [12300/60000 (11%)]	Loss: 0.355746
#
# Test set: Average loss: 0.4386, Accuracy: 8443/10000 (84%)
#
# Train Epoch: 13 [12400/60000 (22%)]	Loss: 0.468238
#
# Test set: Average loss: 0.4385, Accuracy: 8441/10000 (84%)
#
# Train Epoch: 13 [12500/60000 (33%)]	Loss: 0.348349
#
# Test set: Average loss: 0.4383, Accuracy: 8441/10000 (84%)
#
# Train Epoch: 13 [12600/60000 (43%)]	Loss: 0.272665
#
# Test set: Average loss: 0.4383, Accuracy: 8447/10000 (84%)
#
# Train Epoch: 13 [12700/60000 (54%)]	Loss: 0.288877
#
# Test set: Average loss: 0.4381, Accuracy: 8457/10000 (85%)
#
# Train Epoch: 13 [12800/60000 (65%)]	Loss: 0.524625
#
# Test set: Average loss: 0.4387, Accuracy: 8438/10000 (84%)
#
# Train Epoch: 13 [12900/60000 (75%)]	Loss: 0.172891
#
# Test set: Average loss: 0.4384, Accuracy: 8441/10000 (84%)
#
# Train Epoch: 13 [13000/60000 (86%)]	Loss: 0.354470
#
# Test set: Average loss: 0.4386, Accuracy: 8451/10000 (85%)
#
# Train Epoch: 13 [13100/60000 (97%)]	Loss: 0.368377
#
# Test set: Average loss: 0.4384, Accuracy: 8456/10000 (85%)

# %% [markdown]
# ## 0.2 Play with parameters.(3pt)
# How many trainable parameters does the trained model have? The answer needs to depend on the input `model` - outputting a constant number will not get any credits. Hint: Find out how to use model.parameters() in PyTorch.

# %%
def param_count(model):
    params = []
    for param in model.parameters(): # checking number of learned parameters
        params.append(param.numel())
    return sum(params)

print('Model has {} params'.format(param_count(model)))
# Out:
# Model has 454922 params

# %% [markdown]
# ## 0.3 Deep Linear Networks?!? (5pt)
# Until this point, there are no non-linearities in the SimpleCNN! (Your TAs were just as surprised as you are at the results.) Your next task is to modify `simple_cnn.py` to add non-linear activation layers, and train your model in full scale. Make sure to add non-linearities at **every** applicable layer.
#
# Compute the loss and accuracy curves on train and test sets after 5 epochs. The accuracy should be around 90% or higher.

# %%
args.epochs = 5
main()
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.316709
#
# Test set: Average loss: 2.2411, Accuracy: 1487/10000 (15%)
#
# Train Epoch: 0 [100/60000 (11%)]	Loss: 0.713661
#
# Test set: Average loss: 0.6394, Accuracy: 7588/10000 (76%)
#
# Train Epoch: 0 [200/60000 (21%)]	Loss: 0.742926
#
# Test set: Average loss: 0.5443, Accuracy: 8026/10000 (80%)
#
# Train Epoch: 0 [300/60000 (32%)]	Loss: 0.332849
#
# Test set: Average loss: 0.4569, Accuracy: 8286/10000 (83%)
#
# Train Epoch: 0 [400/60000 (43%)]	Loss: 0.302382
#
# Test set: Average loss: 0.4227, Accuracy: 8454/10000 (85%)
#
# Train Epoch: 0 [500/60000 (53%)]	Loss: 0.502598
#
# Test set: Average loss: 0.4040, Accuracy: 8526/10000 (85%)
#
# Train Epoch: 0 [600/60000 (64%)]	Loss: 0.495779
#
# Test set: Average loss: 0.3644, Accuracy: 8683/10000 (87%)
#
# Train Epoch: 0 [700/60000 (75%)]	Loss: 0.358350
#
# Test set: Average loss: 0.3707, Accuracy: 8637/10000 (86%)
#
# Train Epoch: 0 [800/60000 (85%)]	Loss: 0.388437
#
# Test set: Average loss: 0.3485, Accuracy: 8738/10000 (87%)
#
# Train Epoch: 0 [900/60000 (96%)]	Loss: 0.454682
#
# Test set: Average loss: 0.3517, Accuracy: 8730/10000 (87%)
#
# Train Epoch: 1 [1000/60000 (7%)]	Loss: 0.336023
#
# Test set: Average loss: 0.3127, Accuracy: 8855/10000 (89%)
#
# Train Epoch: 1 [1100/60000 (17%)]	Loss: 0.176968
#
# Test set: Average loss: 0.3180, Accuracy: 8847/10000 (88%)
#
# Train Epoch: 1 [1200/60000 (28%)]	Loss: 0.339229
#
# Test set: Average loss: 0.3228, Accuracy: 8812/10000 (88%)
#
# Train Epoch: 1 [1300/60000 (39%)]	Loss: 0.307976
#
# Test set: Average loss: 0.3137, Accuracy: 8856/10000 (89%)
#
# Train Epoch: 1 [1400/60000 (49%)]	Loss: 0.321531
#
# Test set: Average loss: 0.3249, Accuracy: 8794/10000 (88%)
#
# Train Epoch: 1 [1500/60000 (60%)]	Loss: 0.385911
#
# Test set: Average loss: 0.3048, Accuracy: 8908/10000 (89%)
#
# Train Epoch: 1 [1600/60000 (71%)]	Loss: 0.315035
#
# Test set: Average loss: 0.2916, Accuracy: 8930/10000 (89%)
#
# Train Epoch: 1 [1700/60000 (81%)]	Loss: 0.298756
#
# Test set: Average loss: 0.2939, Accuracy: 8943/10000 (89%)
#
# Train Epoch: 1 [1800/60000 (92%)]	Loss: 0.159378
#
# Test set: Average loss: 0.2907, Accuracy: 8923/10000 (89%)
#
# Train Epoch: 2 [1900/60000 (3%)]	Loss: 0.204322
#
# Test set: Average loss: 0.2844, Accuracy: 8964/10000 (90%)
#
# Train Epoch: 2 [2000/60000 (13%)]	Loss: 0.263602
#
# Test set: Average loss: 0.2813, Accuracy: 8990/10000 (90%)
#
# Train Epoch: 2 [2100/60000 (24%)]	Loss: 0.345935
#
# Test set: Average loss: 0.2856, Accuracy: 8955/10000 (90%)
#
# Train Epoch: 2 [2200/60000 (35%)]	Loss: 0.290918
#
# Test set: Average loss: 0.2745, Accuracy: 8988/10000 (90%)
#
# Train Epoch: 2 [2300/60000 (45%)]	Loss: 0.208210
#
# Test set: Average loss: 0.2827, Accuracy: 8975/10000 (90%)
#
# Train Epoch: 2 [2400/60000 (56%)]	Loss: 0.142815
#
# Test set: Average loss: 0.2904, Accuracy: 8927/10000 (89%)
#
# Train Epoch: 2 [2500/60000 (67%)]	Loss: 0.446402
#
# Test set: Average loss: 0.2683, Accuracy: 9023/10000 (90%)
#
# Train Epoch: 2 [2600/60000 (77%)]	Loss: 0.265129
#
# Test set: Average loss: 0.2693, Accuracy: 9030/10000 (90%)
#
# Train Epoch: 2 [2700/60000 (88%)]	Loss: 0.143903
#
# Test set: Average loss: 0.2748, Accuracy: 9003/10000 (90%)
#
# Train Epoch: 2 [2800/60000 (99%)]	Loss: 0.377113
#
# Test set: Average loss: 0.2843, Accuracy: 8963/10000 (90%)
#
# Train Epoch: 3 [2900/60000 (9%)]	Loss: 0.181111
#
# Test set: Average loss: 0.2592, Accuracy: 9062/10000 (91%)
#
# Train Epoch: 3 [3000/60000 (20%)]	Loss: 0.227848
#
# Test set: Average loss: 0.2567, Accuracy: 9069/10000 (91%)
#
# Train Epoch: 3 [3100/60000 (30%)]	Loss: 0.283829
#
# Test set: Average loss: 0.2558, Accuracy: 9070/10000 (91%)
#
# Train Epoch: 3 [3200/60000 (41%)]	Loss: 0.160839
#
# Test set: Average loss: 0.2532, Accuracy: 9102/10000 (91%)
#
# Train Epoch: 3 [3300/60000 (52%)]	Loss: 0.154971
#
# Test set: Average loss: 0.2573, Accuracy: 9063/10000 (91%)
#
# Train Epoch: 3 [3400/60000 (62%)]	Loss: 0.395956
#
# Test set: Average loss: 0.2468, Accuracy: 9110/10000 (91%)
#
# Train Epoch: 3 [3500/60000 (73%)]	Loss: 0.181368
#
# Test set: Average loss: 0.2588, Accuracy: 9059/10000 (91%)
#
# Train Epoch: 3 [3600/60000 (84%)]	Loss: 0.246464
#
# Test set: Average loss: 0.2532, Accuracy: 9093/10000 (91%)
#
# Train Epoch: 3 [3700/60000 (94%)]	Loss: 0.242790
#
# Test set: Average loss: 0.2486, Accuracy: 9085/10000 (91%)
#
# Train Epoch: 4 [3800/60000 (5%)]	Loss: 0.209371
#
# Test set: Average loss: 0.2475, Accuracy: 9114/10000 (91%)
#
# Train Epoch: 4 [3900/60000 (16%)]	Loss: 0.126900
#
# Test set: Average loss: 0.2460, Accuracy: 9093/10000 (91%)
#
# Train Epoch: 4 [4000/60000 (26%)]	Loss: 0.151121
#
# Test set: Average loss: 0.2469, Accuracy: 9110/10000 (91%)
#
# Train Epoch: 4 [4100/60000 (37%)]	Loss: 0.135448
#
# Test set: Average loss: 0.2453, Accuracy: 9118/10000 (91%)
#
# Train Epoch: 4 [4200/60000 (48%)]	Loss: 0.232541
#
# Test set: Average loss: 0.2442, Accuracy: 9127/10000 (91%)
#
# Train Epoch: 4 [4300/60000 (58%)]	Loss: 0.085414
#
# Test set: Average loss: 0.2450, Accuracy: 9105/10000 (91%)
#
# Train Epoch: 4 [4400/60000 (69%)]	Loss: 0.237122
#
# Test set: Average loss: 0.2474, Accuracy: 9091/10000 (91%)
#
# Train Epoch: 4 [4500/60000 (80%)]	Loss: 0.164106
#
# Test set: Average loss: 0.2404, Accuracy: 9120/10000 (91%)
#
# Train Epoch: 4 [4600/60000 (90%)]	Loss: 0.332437
#
# Test set: Average loss: 0.2408, Accuracy: 9136/10000 (91%)
# SimpleCNN(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (nonlinear): ReLU()
#   (pool1): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (pool2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (fc1): Sequential(
#     (0): Linear(in_features=3136, out_features=128, bias=True)
#     (1): ReLU()
#   )
#   (fc2): Sequential(
#     (0): Linear(in_features=128, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# Where did you add your non-linearities?
#
# **YOUR ANSWER HERE**
#
#
# <br><br><br>
# Provide some insights on why the results was fairly good even without activation layers. (**2** pts)
#
# **YOUR ANSWER HERE**
